# %%
require './moromoro'
# Out:
# true

# %%
def angle_to_radian(angle)
  (angle.to_f / 360.0) * 2 * Math::PI
end
# Out:
# :angle_to_radian

# %%
# 右は次数mが正、左は次数mが負
# D: 0 → 区別なし, 1 → D1, 2 → D2
a_df = <<DATA.to_df
m, D, degree, minute, second
0, 0, 0, 0, 0
1, 0, 6, 47, 0
2, 0, 13, 39, 0
3, 2, 20, 42, 30
3, 1, 20, 44, 0
4, 2, 28, 8, 0
4, 1, 28, 10, 0
5, 2, 36, 7, 0
5, 1, 36, 9, 0
6, 2, 45, 1, 0
6, 1, 45, 4, 30
7, 2, 55, 37, 0
7, 1, 55, 41, 0
8, 2, 70, 25, 30
8, 1, 70, 34, 30
-1, 0, 6, 45, 30
-2, 0, 13, 38, 30
-3, 2, 20, 42, 30
-3, 1, 20, 43, 30
-4, 2, 28, 7, 30
-4, 1, 28, 9, 30
-5, 2, 36, 7, 0
-5, 1, 36, 9, 30
-6, 2, 45, 1, 0
-6, 1, 45, 5, 0
-7, 2, 55, 37, 30
-7, 1, 55, 42, 30
-8, 2, 70, 36, 0
-8, 1, 70, 47, 30
DATA
a_df.save_csv('csv/raw_data.csv')
a_radianed = a_df.map do |row|
  row.merge({ 'angle' => "#{row['degree'].to_i}°#{row['minute'].to_i}′#{row['second'].to_i}″", 'theta[rad]' => angle_to_radian(row['degree'] + row['minute']/60.0 + row['second']/3600.0) })
end.reset
nil

# %%
(0.5/60.to_f)/360 * 2 * Math::PI
# Out:
# 0.0001454441043328608

# %%
ideal = { 1 => 589.592, 2 => 588.995 }
n = 2000 * 100
delta_theta = p (2/60.to_f)/360 * 2 * Math::PI #7.3 * 10**(-5)
a_with_calc = a_radianed.group_by { |row| [row['m'].abs, row['D']] }.map do |(m, d), v|
  two_theta_m = v.map { |row| row['theta[rad]'] }.inject(:+)
  theta_m = two_theta_m / 2
  lamb = Math.sin(two_theta_m/2)/(m * n)
  delta_lambda = (lamb.abs * delta_theta / Math.tan(theta_m) * 10**9).round(2)
  error = (ideal[d.to_i] || 0) - (lamb * 10**9)
  {
    'm' => m.to_i,
    'D' => d.to_i,
    'angle_left' => v.find { |row| row['m'] < 0.0 }&.fetch('angle') { nil } || v.first['angle'],
    'angle_right' => v.find { |row| row['m'] > 0.0 }&.fetch('angle') { nil } || v.first['angle'],
    '2_theta_m' => two_theta_m.round(4),
    'theta_m' => theta_m.round(4),
    'sin_theta_m' => Math.sin(theta_m).round(4),
    'lambda[nm]' => (lamb * 10**9),
    'delta_lambda[nm]' => delta_lambda,
    'ideal[nm]' => ideal[d.to_i],
    'in_error?' => error.abs - delta_lambda,
    'error' => error,
  }
end.to_df
# Out:
# [{"m"=>0, "D"=>0, "angle_left"=>"0°0′0″", "angle_right"=>"0°0′0″", "2_theta_m"=>0.0, "theta_m"=>0.0, "sin_theta_m"=>0.0, "lambda[nm]"=>NaN, "delta_lambda[nm]"=>NaN, "ideal[nm]"=>nil, "in_error?"=>NaN, "error"=>NaN}, {"m"=>1, "D"=>0, "angle_left"=>"6°45′30″", "angle_right"=>"6°47′0″", "2_theta_m"=>0.2363, "theta_m"=>0.1182, "sin_theta_m"=>0.1179, "lambda[nm]"=>589.4923978029327, "delta_lambda[nm]"=>0.36, "ideal[nm]"=>nil, "in_error?"=>589.1323978029327, "error"=>-589.4923978029327}, {"m"=>2, "D"=>0, "angle_left"=>"13°38′30″", "angle_right"=>"13°39′0″", "2_theta_m"=>0.4763, "theta_m"=>0.2382, "sin_theta_m"=>0.2359, "lambda[nm]"=>589.7988769236579, "delta_lambda[nm]"=>0.18, "ideal[nm]"=>nil, "in_error?"=>589.6188769236579, "error"=>-589.7988769236579}, {"m"=>3, "D"=>2, "angle_left"=>"20°42′30″", "angle_right"=>"20°42′30″", "2_theta_m"=>0.7229, "theta_m"=>0.3614, "sin_theta_m"=>0.3536, "lambda[nm]"=>589.3514914321562, "delta_lambda[nm]"=>0.11, "ideal[nm]"=>588.995, "in_error?"=>0.24649143215619007, "error"=>-0.35649143215619006}, {"m"=>3, "D"=>1, "angle_left"=>"20°43′30″", "angle_right"=>"20°44′0″", "2_theta_m"=>0.7236, "theta_m"=>0.3618, "sin_theta_m"=>0.354, "lambda[nm]"=>589.9183163781055, "delta_lambda[nm]"=>0.11, "ideal[nm]"=>589.592, "in_error?"=>0.21631637810550275, "error"=>-0.32631637810550274}, {"m"=>4, "D"=>2, "angle_left"=>"28°7′30″", "angle_right"=>"28°8′0″", "2_theta_m"=>0.9819, "theta_m"=>0.4909, "sin_theta_m"=>0.4715, "lambda[nm]"=>589.3260883795546, "delta_lambda[nm]"=>0.08, "ideal[nm]"=>588.995, "in_error?"=>0.2510883795545578, "error"=>-0.33108837955455783}, {"m"=>4, "D"=>1, "angle_left"=>"28°9′30″", "angle_right"=>"28°10′0″", "2_theta_m"=>0.9831, "theta_m"=>0.4915, "sin_theta_m"=>0.472, "lambda[nm]"=>589.9673149210349, "delta_lambda[nm]"=>0.08, "ideal[nm]"=>589.592, "in_error?"=>0.295314921034942, "error"=>-0.375314921034942}, {"m"=>5, "D"=>2, "angle_left"=>"36°7′0″", "angle_right"=>"36°7′0″", "2_theta_m"=>1.2607, "theta_m"=>0.6304, "sin_theta_m"=>0.5894, "lambda[nm]"=>589.4313671522699, "delta_lambda[nm]"=>0.06, "ideal[nm]"=>588.995, "in_error?"=>0.3763671522698951, "error"=>-0.4363671522698951}, {"m"=>5, "D"=>1, "angle_left"=>"36°9′30″", "angle_right"=>"36°9′0″", "2_theta_m"=>1.262, "theta_m"=>0.631, "sin_theta_m"=>0.59, "lambda[nm]"=>589.959956813024, "delta_lambda[nm]"=>0.06, "ideal[nm]"=>589.592, "in_error?"=>0.3079568130239659, "error"=>-0.3679568130239659}, {"m"=>6, "D"=>2, "angle_left"=>"45°1′0″", "angle_right"=>"45°1′0″", "2_theta_m"=>1.5714, "theta_m"=>0.7857, "sin_theta_m"=>0.7073, "lambda[nm]"=>589.4270335769214, "delta_lambda[nm]"=>0.04, "ideal[nm]"=>588.995, "in_error?"=>0.39203357692141255, "error"=>-0.43203357692141253}, {"m"=>6, "D"=>1, "angle_left"=>"45°5′0″", "angle_right"=>"45°4′30″", "2_theta_m"=>1.5736, "theta_m"=>0.7868, "sin_theta_m"=>0.7081, "lambda[nm]"=>590.0692739654949, "delta_lambda[nm]"=>0.04, "ideal[nm]"=>589.592, "in_error?"=>0.4372739654948737, "error"=>-0.47727396549487366}, {"m"=>7, "D"=>2, "angle_left"=>"55°37′30″", "angle_right"=>"55°37′0″", "2_theta_m"=>1.9415, "theta_m"=>0.9708, "sin_theta_m"=>0.8253, "lambda[nm]"=>589.5134796629421, "delta_lambda[nm]"=>0.03, "ideal[nm]"=>588.995, "in_error?"=>0.4884796629421271, "error"=>-0.5184796629421271}, {"m"=>7, "D"=>1, "angle_left"=>"55°42′30″", "angle_right"=>"55°41′0″", "2_theta_m"=>1.9442, "theta_m"=>0.9721, "sin_theta_m"=>0.8261, "lambda[nm]"=>590.0409368147592, "delta_lambda[nm]"=>0.03, "ideal[nm]"=>589.592, "in_error?"=>0.41893681475923583, "error"=>-0.44893681475923586}, {"m"=>8, "D"=>2, "angle_left"=>"70°36′0″", "angle_right"=>"70°25′30″", "2_theta_m"=>2.4614, "theta_m"=>1.2307, "sin_theta_m"=>0.9427, "lambda[nm]"=>589.1964337611802, "delta_lambda[nm]"=>0.02, "ideal[nm]"=>588.995, "in_error?"=>0.18143376118016932, "error"=>-0.2014337611801693}, {"m"=>8, "D"=>1, "angle_left"=>"70°47′30″", "angle_right"=>"70°34′30″", "2_theta_m"=>2.4673, "theta_m"=>1.2337, "sin_theta_m"=>0.9437, "lambda[nm]"=>589.8154805716524, "delta_lambda ...

# %%
a_with_calc.map do |row|
  {
    'm' => row['m'],
    'D' => row['D'] == 0 ? '' : "$ D_#{row['D']} $",
    'angle(left)' => row['angle_left'],
    'angle(right)' => row['angle_right'],
    '\theta_m' => row['theta_m'],
    '\sin\theta_m' => row['sin_theta_m'],
    '\lambda[nm]' => row['lambda[nm]'].round(2),
    '\Delta\lambda_m[nm]' => row['delta_lambda[nm]'],
  }
end.to_df.save_csv('csv/data.csv')
# Out:
# "csv/data.csv"

# %%
a_with_calc.plot(
  targets: [
    { function: '589.592', w: :lines, title: 'D_1', lt: 1 },
    { function: '588.995', w: :lines, title: 'D_2', lt: 2 },
    { x: 'm', y: 'lambda[nm]', yerror: 'delta_lambda[nm]', with: :yerrorbars, lt: 6 },
  ],
  options: {
    xrange: '[0:9]',
  },
  file: 'graph/a_with_calc.png'
)
# Out:
# line 16: warning: Skipping data file with no valid points
#          line 32: warning: Skipping data file with no valid points
# line 64: warning: Skipping data file with no valid points
#          line 80: warning: Skipping data file with no valid points
# #<Numo::Gnuplot::NotePlot:0x007fd3841aee60 @block=#<Proc:0x007fd3841aee88@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_12_01/moromoro.rb:127>>

# %%
a_with_calc.select { |row| row['D'] > 0 }.group_by { |row| row['D'] }.each do |d, rows|
  lm = rows.map { |row| row['lambda[nm]'] }.inject(:+) / rows.size.to_f
  puts "#{d}: #{lm.round(1)}, #{ideal[d]}, #{((ideal[d] - lm.round(1))/ideal[d] * 100).abs.round(2)}%"
end
nil
# Out:
# 2: 589.4, 588.995, 0.07%
# 1: 590.0, 589.592, 0.07%

# %%
a_with_calc.select { |row| row['D'] > 0 }.group_by { |row| row['D'] }.each do |d, rows|
  with_weight = rows.map { |row| row.merge('weight' => 1/row['delta_lambda[nm]']**2) }
  lm = with_weight.map { |row| row['lambda[nm]']*row['weight'] }.inject(:+) / with_weight.map { |row| row['weight'] }.inject(:+)
  puts "#{d}: #{lm.round(1)}, #{ideal[d]}, #{((ideal[d] - lm.round(1))/ideal[d] * 100).abs.round(2)}%"
end
nil
# Out:
# 2: 589.3, 588.995, 0.05%
# 1: 589.9, 589.592, 0.05%

# %%
a_with_calc.select{ |row| row['D'] == 1 }.to_df.plot(
  targets: [ { x: 'm', y: 'error' } ]
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007fd383ef0b38 @block=#<Proc:0x007fd383ef0b60@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_12_01/moromoro.rb:127>>

# %%
a_with_calc.select{ |row| row['D'] == 2 }.to_df.plot(
  targets: [ { x: 'm', y: 'error' } ]
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007fd3859e0678 @block=#<Proc:0x007fd3859e06a0@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_12_01/moromoro.rb:127>>

# %%
a_with_calc_only_2 = a_with_calc.select { |row| row['D'] > 0 }.to_df
# Out:
# [{"m"=>3, "D"=>2, "angle_left"=>"20°42′30″", "angle_right"=>"20°42′30″", "2_theta_m"=>0.7229, "theta_m"=>0.3614, "sin_theta_m"=>0.3536, "lambda[nm]"=>589.3514914321562, "delta_lambda[nm]"=>0.11, "ideal[nm]"=>588.995, "in_error?"=>0.24649143215619007, "error"=>-0.35649143215619006}, {"m"=>3, "D"=>1, "angle_left"=>"20°43′30″", "angle_right"=>"20°44′0″", "2_theta_m"=>0.7236, "theta_m"=>0.3618, "sin_theta_m"=>0.354, "lambda[nm]"=>589.9183163781055, "delta_lambda[nm]"=>0.11, "ideal[nm]"=>589.592, "in_error?"=>0.21631637810550275, "error"=>-0.32631637810550274}, {"m"=>4, "D"=>2, "angle_left"=>"28°7′30″", "angle_right"=>"28°8′0″", "2_theta_m"=>0.9819, "theta_m"=>0.4909, "sin_theta_m"=>0.4715, "lambda[nm]"=>589.3260883795546, "delta_lambda[nm]"=>0.08, "ideal[nm]"=>588.995, "in_error?"=>0.2510883795545578, "error"=>-0.33108837955455783}, {"m"=>4, "D"=>1, "angle_left"=>"28°9′30″", "angle_right"=>"28°10′0″", "2_theta_m"=>0.9831, "theta_m"=>0.4915, "sin_theta_m"=>0.472, "lambda[nm]"=>589.9673149210349, "delta_lambda[nm]"=>0.08, "ideal[nm]"=>589.592, "in_error?"=>0.295314921034942, "error"=>-0.375314921034942}, {"m"=>5, "D"=>2, "angle_left"=>"36°7′0″", "angle_right"=>"36°7′0″", "2_theta_m"=>1.2607, "theta_m"=>0.6304, "sin_theta_m"=>0.5894, "lambda[nm]"=>589.4313671522699, "delta_lambda[nm]"=>0.06, "ideal[nm]"=>588.995, "in_error?"=>0.3763671522698951, "error"=>-0.4363671522698951}, {"m"=>5, "D"=>1, "angle_left"=>"36°9′30″", "angle_right"=>"36°9′0″", "2_theta_m"=>1.262, "theta_m"=>0.631, "sin_theta_m"=>0.59, "lambda[nm]"=>589.959956813024, "delta_lambda[nm]"=>0.06, "ideal[nm]"=>589.592, "in_error?"=>0.3079568130239659, "error"=>-0.3679568130239659}, {"m"=>6, "D"=>2, "angle_left"=>"45°1′0″", "angle_right"=>"45°1′0″", "2_theta_m"=>1.5714, "theta_m"=>0.7857, "sin_theta_m"=>0.7073, "lambda[nm]"=>589.4270335769214, "delta_lambda[nm]"=>0.04, "ideal[nm]"=>588.995, "in_error?"=>0.39203357692141255, "error"=>-0.43203357692141253}, {"m"=>6, "D"=>1, "angle_left"=>"45°5′0″", "angle_right"=>"45°4′30″", "2_theta_m"=>1.5736, "theta_m"=>0.7868, "sin_theta_m"=>0.7081, "lambda[nm]"=>590.0692739654949, "delta_lambda[nm]"=>0.04, "ideal[nm]"=>589.592, "in_error?"=>0.4372739654948737, "error"=>-0.47727396549487366}, {"m"=>7, "D"=>2, "angle_left"=>"55°37′30″", "angle_right"=>"55°37′0″", "2_theta_m"=>1.9415, "theta_m"=>0.9708, "sin_theta_m"=>0.8253, "lambda[nm]"=>589.5134796629421, "delta_lambda[nm]"=>0.03, "ideal[nm]"=>588.995, "in_error?"=>0.4884796629421271, "error"=>-0.5184796629421271}, {"m"=>7, "D"=>1, "angle_left"=>"55°42′30″", "angle_right"=>"55°41′0″", "2_theta_m"=>1.9442, "theta_m"=>0.9721, "sin_theta_m"=>0.8261, "lambda[nm]"=>590.0409368147592, "delta_lambda[nm]"=>0.03, "ideal[nm]"=>589.592, "in_error?"=>0.41893681475923583, "error"=>-0.44893681475923586}, {"m"=>8, "D"=>2, "angle_left"=>"70°36′0″", "angle_right"=>"70°25′30″", "2_theta_m"=>2.4614, "theta_m"=>1.2307, "sin_theta_m"=>0.9427, "lambda[nm]"=>589.1964337611802, "delta_lambda[nm]"=>0.02, "ideal[nm]"=>588.995, "in_error?"=>0.18143376118016932, "error"=>-0.2014337611801693}, {"m"=>8, "D"=>1, "angle_left"=>"70°47′30″", "angle_right"=>"70°34′30″", "2_theta_m"=>2.4673, "theta_m"=>1.2337, "sin_theta_m"=>0.9437, "lambda[nm]"=>589.8154805716524, "delta_lambda[nm]"=>0.02, "ideal[nm]"=>589.592, "in_error?"=>0.20348057165243064, "error"=>-0.22348057165243063}]

# %%
a_with_calc_only_2.map do |row|
  {
    '[nm]' => ideal[row['D']] - row['lambda[nm]'],
    '1/m' => 1.to_f/row['m']
  }
end.to_df.plot(
  targets: [{x: '1/m', y: '[nm]', title: 'hoge'}],
  options: {
    xrange: '[0.1:0.4]',
    yrange: '[-0.55:-0.2]'
  }
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007fd385c57488 @block=#<Proc:0x007fd385c574b0@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_12_01/moromoro.rb:127>>

# %%
a_radianed.group_by { |row| [row['m'], row['D']] }.map do |(m, d), v|
  two_theta_m = v.map { |row| row['theta[rad]'] }.inject(:+)
  theta_m = two_theta_m
  lamb = Math.sin(theta_m)/(m.abs * n)
  delta_lambda = (lamb.abs * delta_theta / Math.tan(theta_m) * 10**9).round(2)
  error = (ideal[d.to_i] || 0) - (lamb * 10**9)
  {
    'm' => m.to_i,
    'D' => d.to_i,
    'angle_left' => v.find { |row| row['m'] < 0.0 }&.fetch('angle') { nil } || v.first['angle'],
    'angle_right' => v.find { |row| row['m'] > 0.0 }&.fetch('angle') { nil } || v.first['angle'],
    '2_theta_m' => two_theta_m.round(4),
    'theta_m' => theta_m.round(4),
    'sin_theta_m' => Math.sin(theta_m).round(4),
    'lambda[nm]' => (lamb * 10**9),
    'delta_lambda[nm]' => delta_lambda,
    'ideal[nm]' => ideal[d.to_i],
    'in_error?' => error.abs - delta_lambda,
    'error' => error,
  }
end.to_df.plot(
  targets: [
    { function: '589.592', w: :lines, title: 'D_1', lt: 1 },
    { function: '588.995', w: :lines, title: 'D_2', lt: 2 },
    { x: 'm', y: 'lambda[nm]', yerror: 'delta_lambda[nm]', with: :yerrorbars, lt: 6 },
  ],
)
# Out:
# line 621: warning: Skipping data file with no valid points
#          line 651: warning: Skipping data file with no valid points
# #<Numo::Gnuplot::NotePlot:0x007fd3843a90f8 @block=#<Proc:0x007fd3843a9120@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_12_01/moromoro.rb:127>>
