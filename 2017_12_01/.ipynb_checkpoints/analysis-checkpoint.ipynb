# %%
require './moromoro'
# Out:
# true

# %%
def angle_to_radian(angle)
  (angle.to_f / 360.0) * 2 * Math::PI
end
# Out:
# :angle_to_radian

# %%
# 右は次数mが正、左は次数mが負
# D: 0 → 区別なし, 1 → D1, 2 → D2
a_df = <<DATA.to_df
m, D, degree, minute, second
0, 0, 0, 0, 0
1, 0, 6, 47, 0
2, 0, 13, 39, 0
3, 1, 20, 42, 30
3, 2, 20, 44, 0
4, 1, 28, 8, 0
4, 2, 28, 10, 0
5, 1, 36, 7, 0
5, 2, 36, 9, 0
6, 1, 45, 1, 0
6, 2, 45, 4, 30
7, 1, 55, 37, 0
7, 2, 55, 41, 0
8, 1, 70, 25, 30
8, 2, 70, 34, 30
-1, 0, 6, 45, 30
-2, 0, 13, 38, 30
-3, 1, 20, 42, 30
-3, 2, 20, 43, 30
-4, 1, 28, 7, 30
-4, 2, 28, 9, 30
-5, 1, 36, 7, 0
-5, 2, 26, 9, 30
-6, 1, 45, 1, 0
-6, 2, 45, 5, 0
-7, 1, 55, 37, 30
-7, 2, 55, 42, 30
-8, 1, 70, 36, 0
-8, 2, 70, 47, 30
DATA
a_radianed = a_df.map do |row|
  row.merge({ 'angle' => "#{row['degree'].to_i}°#{row['minute'].to_i}′#{row['second'].to_i}″", 'theta[rad]' => angle_to_radian(row['degree'] + row['minute']/60.0 + row['second']/3600.0) })
end.reset
nil

# %%
n = 2000 * 100
delta_theta = 7.3 * 10**(-5)
a_radianed.group_by { |row| [row['m'].abs, row['D']] }.map do |(m, d), v|
  two_theta_m = v.map { |row| row['theta[rad]'] }.inject(:+)
  theta_m = two_theta_m / 2
  lamb = Math.sin(two_theta_m/2)/(m * n)
  {
    'm' => m,
    'angle_left' => v.find { |row| row['m'] < 0.0 }&.fetch('angle') { nil } || v.first['angle'],
    'angle_right' => v.find { |row| row['m'] > 0.0 }&.fetch('angle') { nil } || v.first['angle'],
    '2_theta_m' => two_theta_m.round(4),
    'theta_m' => theta_m.round(4),
    'sin_theta_m' => Math.sin(theta_m).round(4),
    'lambda[nm]' => (lamb * 10**9).round(1),
    'delta_lambda[nm]' => (lamb.abs * delta_theta / Math.tan(theta_m) * 10**9).round(2)
  }
end.to_df
# Out:
# [{"m"=>0.0, "angle_left"=>"0°0′0″", "angle_right"=>"0°0′0″", "2_theta_m"=>0.0, "theta_m"=>0.0, "sin_theta_m"=>0.0, "lambda[nm]"=>NaN, "delta_lambda[nm]"=>NaN}, {"m"=>1.0, "angle_left"=>"6°45′30″", "angle_right"=>"6°47′0″", "2_theta_m"=>0.2363, "theta_m"=>0.1182, "sin_theta_m"=>0.1179, "lambda[nm]"=>589.5, "delta_lambda[nm]"=>0.36}, {"m"=>2.0, "angle_left"=>"13°38′30″", "angle_right"=>"13°39′0″", "2_theta_m"=>0.4763, "theta_m"=>0.2382, "sin_theta_m"=>0.2359, "lambda[nm]"=>589.8, "delta_lambda[nm]"=>0.18}, {"m"=>3.0, "angle_left"=>"20°42′30″", "angle_right"=>"20°42′30″", "2_theta_m"=>0.7229, "theta_m"=>0.3614, "sin_theta_m"=>0.3536, "lambda[nm]"=>589.4, "delta_lambda[nm]"=>0.11}, {"m"=>3.0, "angle_left"=>"20°43′30″", "angle_right"=>"20°44′0″", "2_theta_m"=>0.7236, "theta_m"=>0.3618, "sin_theta_m"=>0.354, "lambda[nm]"=>589.9, "delta_lambda[nm]"=>0.11}, {"m"=>4.0, "angle_left"=>"28°7′30″", "angle_right"=>"28°8′0″", "2_theta_m"=>0.9819, "theta_m"=>0.4909, "sin_theta_m"=>0.4715, "lambda[nm]"=>589.3, "delta_lambda[nm]"=>0.08}, {"m"=>4.0, "angle_left"=>"28°9′30″", "angle_right"=>"28°10′0″", "2_theta_m"=>0.9831, "theta_m"=>0.4915, "sin_theta_m"=>0.472, "lambda[nm]"=>590.0, "delta_lambda[nm]"=>0.08}, {"m"=>5.0, "angle_left"=>"36°7′0″", "angle_right"=>"36°7′0″", "2_theta_m"=>1.2607, "theta_m"=>0.6304, "sin_theta_m"=>0.5894, "lambda[nm]"=>589.4, "delta_lambda[nm]"=>0.06}, {"m"=>5.0, "angle_left"=>"26°9′30″", "angle_right"=>"36°9′0″", "2_theta_m"=>1.0875, "theta_m"=>0.5437, "sin_theta_m"=>0.5173, "lambda[nm]"=>517.3, "delta_lambda[nm]"=>0.06}, {"m"=>6.0, "angle_left"=>"45°1′0″", "angle_right"=>"45°1′0″", "2_theta_m"=>1.5714, "theta_m"=>0.7857, "sin_theta_m"=>0.7073, "lambda[nm]"=>589.4, "delta_lambda[nm]"=>0.04}, {"m"=>6.0, "angle_left"=>"45°5′0″", "angle_right"=>"45°4′30″", "2_theta_m"=>1.5736, "theta_m"=>0.7868, "sin_theta_m"=>0.7081, "lambda[nm]"=>590.1, "delta_lambda[nm]"=>0.04}, {"m"=>7.0, "angle_left"=>"55°37′30″", "angle_right"=>"55°37′0″", "2_theta_m"=>1.9415, "theta_m"=>0.9708, "sin_theta_m"=>0.8253, "lambda[nm]"=>589.5, "delta_lambda[nm]"=>0.03}, {"m"=>7.0, "angle_left"=>"55°42′30″", "angle_right"=>"55°41′0″", "2_theta_m"=>1.9442, "theta_m"=>0.9721, "sin_theta_m"=>0.8261, "lambda[nm]"=>590.0, "delta_lambda[nm]"=>0.03}, {"m"=>8.0, "angle_left"=>"70°36′0″", "angle_right"=>"70°25′30″", "2_theta_m"=>2.4614, "theta_m"=>1.2307, "sin_theta_m"=>0.9427, "lambda[nm]"=>589.2, "delta_lambda[nm]"=>0.02}, {"m"=>8.0, "angle_left"=>"70°47′30″", "angle_right"=>"70°34′30″", "2_theta_m"=>2.4673, "theta_m"=>1.2337, "sin_theta_m"=>0.9437, "lambda[nm]"=>589.8, "delta_lambda[nm]"=>0.02}]

# %%
{ a: 1, b: 2 }[:a]
# Out:
# 1

# %%
a_df.plot(
  targets: [{ x: 'y[m]', y: 'time[s]' }],
  options: {},
  file: 'graph/a_with_model.png'
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007ff892a3a100 @block=#<Proc:0x007ff892a3a128@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_12_01/moromoro.rb:125>>
