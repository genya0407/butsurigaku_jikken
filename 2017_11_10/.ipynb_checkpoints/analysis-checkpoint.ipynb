# %%
require './moromoro'
# Out:
# true

# %%
a_df = <<DATA.to_df
m[kg], x[cm], N , y[cm], time[s]
0.35,  5,     30, 30.1 , 34.31
0.35,  5,     30, 35.1 , 36.37
0.35,  5,     30, 40.1 , 38.30
0.35,  5,     30, 45.1 , 40.14
0.35,  5,     30, 50.1 , 42.05
0.35,  5,     30, 55.1 , 43.85
0.35,  5,     30, 60.1 , 45.89
DATA
# Out:
# [{"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>30.1, "time[s]"=>34.31}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>35.1, "time[s]"=>36.37}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>40.1, "time[s]"=>38.3}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>45.1, "time[s]"=>40.14}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>50.1, "time[s]"=>42.05}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>55.1, "time[s]"=>43.85}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>60.1, "time[s]"=>45.89}]

# %%
def f_model(y)
  g = 9.80665 # m/s^2
  1.to_f/ (2*Math::PI) * Math.sqrt(g/y)
end
# Out:
# :f_model

# %%
a_with_calc_df = a_df.map do |row|
  t = row['time[s]'].to_f / row['N'].to_f
  f = 1/t
  y = row['y[cm]'] / 100.to_f
  x = row['x[cm]'] / 100.to_f
  row.merge(
    'y[m]' => y,
    'x[m]' => x,
    'T[s]' => t,
    'f[Hz]' => f,
    'f_model[Hz]' => f_model(y)
  )
end.to_a.to_df
# Out:
# [{"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>30.1, "time[s]"=>34.31, "y[m]"=>0.301, "x[m]"=>0.05, "T[s]"=>1.1436666666666668, "f[Hz]"=>0.8743806470416787, "f_model[Hz]"=>0.9084420353183422}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>35.1, "time[s]"=>36.37, "y[m]"=>0.35100000000000003, "x[m]"=>0.05, "T[s]"=>1.2123333333333333, "f[Hz]"=>0.8248556502612043, "f_model[Hz]"=>0.8412535524899832}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>40.1, "time[s]"=>38.3, "y[m]"=>0.401, "x[m]"=>0.05, "T[s]"=>1.2766666666666666, "f[Hz]"=>0.783289817232376, "f_model[Hz]"=>0.7870608008396089}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>45.1, "time[s]"=>40.14, "y[m]"=>0.451, "x[m]"=>0.05, "T[s]"=>1.338, "f[Hz]"=>0.7473841554559043, "f_model[Hz]"=>0.7421508658903243}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>50.1, "time[s]"=>42.05, "y[m]"=>0.501, "x[m]"=>0.05, "T[s]"=>1.4016666666666666, "f[Hz]"=>0.713436385255648, "f_model[Hz]"=>0.7041442001988787}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>55.1, "time[s]"=>43.85, "y[m]"=>0.551, "x[m]"=>0.05, "T[s]"=>1.4616666666666667, "f[Hz]"=>0.6841505131128849, "f_model[Hz]"=>0.6714360728949803}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>60.1, "time[s]"=>45.89, "y[m]"=>0.601, "x[m]"=>0.05, "T[s]"=>1.5296666666666667, "f[Hz]"=>0.653737197646546, "f_model[Hz]"=>0.6428997152843516}]

# %%
a_with_calc_df.plot(
  targets: [{ x: 'y[m]', y: 'f[Hz]' }, { x: 'y[m]', y: 'f_model[Hz]' }],
  options: {},
  file: 'graph/a.png'
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007ffbc1575408 @block=#<Proc:0x007ffbc15754d0@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_11_10/moromoro.rb:99>>
