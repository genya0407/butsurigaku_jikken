# %%
require './moromoro'
# Out:
# true

# %%
a_df = <<DATA.to_df
m[kg], x[cm], N , y[cm], time[s]
0.35,  5,     30, 30.1 , 34.31
0.35,  5,     30, 35.1 , 36.37
0.35,  5,     30, 40.1 , 38.30
0.35,  5,     30, 45.1 , 40.14
0.35,  5,     30, 50.1 , 42.05
0.35,  5,     30, 55.1 , 43.85
0.35,  5,     30, 60.1 , 45.89
DATA
# Out:
# [{"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>30.1, "time[s]"=>34.31}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>35.1, "time[s]"=>36.37}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>40.1, "time[s]"=>38.3}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>45.1, "time[s]"=>40.14}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>50.1, "time[s]"=>42.05}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>55.1, "time[s]"=>43.85}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>60.1, "time[s]"=>45.89}]

# %%
a_df.map { |row| { 'y[cm]' => row['y[cm]'], 'time[s]' => row['time[s]'] } }.reset.save_csv('csv/A.csv')
# Out:
# "csv/A.csv"

# %%
def f_model(y)
  g = 9.797 # m/s^2
  1.to_f/ (2*Math::PI) * Math.sqrt(g/y)
end
# Out:
# :f_model

# %%
a_with_calc_df = a_df.map do |row|
  t = row['time[s]'].to_f / row['N'].to_f
  f = 1/t
  y = row['y[cm]'] / 100.to_f
  x = row['x[cm]'] / 100.to_f
  f_absolute_error = (f_model(y) - f).abs
  row.merge(
    'y[m]' => y,
    'x[m]' => x,
    'T[s]' => t,
    'f[Hz]' => f,
    'f_model[Hz]' => f_model(y),
    'f_model_possible_error[Hz]' => 30.0/row['time[s]']**2 * 0.2,
    'f_absolute_error[Hz]' => f_absolute_error,
    'f_relative_error[%]' => f_absolute_error / f_model(y) * 100
  )
end.reset
# Out:
# [{"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>30.1, "time[s]"=>34.31, "y[m]"=>0.301, "x[m]"=>0.05, "T[s]"=>1.1436666666666668, "f[Hz]"=>0.8743806470416787, "f_model[Hz]"=>0.9079949599505865, "f_model_possible_error[Hz]"=>0.005096943439473499, "f_absolute_error[Hz]"=>0.03361431290890782, "f_relative_error[%]"=>3.702037389143341}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>35.1, "time[s]"=>36.37, "y[m]"=>0.35100000000000003, "x[m]"=>0.05, "T[s]"=>1.2123333333333333, "f[Hz]"=>0.8248556502612043, "f_model[Hz]"=>0.8408395428705104, "f_model_possible_error[Hz]"=>0.004535912291785562, "f_absolute_error[Hz]"=>0.015983892609306105, "f_relative_error[%]"=>1.9009444482997666}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>40.1, "time[s]"=>38.3, "y[m]"=>0.401, "x[m]"=>0.05, "T[s]"=>1.2766666666666666, "f[Hz]"=>0.783289817232376, "f_model[Hz]"=>0.7866734613250321, "f_model_possible_error[Hz]"=>0.004090286251866194, "f_absolute_error[Hz]"=>0.003383644092656124, "f_relative_error[%]"=>0.4301205339960101}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>45.1, "time[s]"=>40.14, "y[m]"=>0.451, "x[m]"=>0.05, "T[s]"=>1.338, "f[Hz]"=>0.7473841554559043, "f_model[Hz]"=>0.7417856280893437, "f_model_possible_error[Hz]"=>0.003723887172176902, "f_absolute_error[Hz]"=>0.005598527366560635, "f_relative_error[%]"=>0.7547365646569693}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>50.1, "time[s]"=>42.05, "y[m]"=>0.501, "x[m]"=>0.05, "T[s]"=>1.4016666666666666, "f[Hz]"=>0.713436385255648, "f_model[Hz]"=>0.7037976667768022, "f_model_possible_error[Hz]"=>0.003393276505377637, "f_absolute_error[Hz]"=>0.009638718478845787, "f_relative_error[%]"=>1.3695297574640224}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>55.1, "time[s]"=>43.85, "y[m]"=>0.551, "x[m]"=>0.05, "T[s]"=>1.4616666666666667, "f[Hz]"=>0.6841505131128849, "f_model[Hz]"=>0.6711056362600124, "f_model_possible_error[Hz]"=>0.0031204128306174905, "f_absolute_error[Hz]"=>0.013044876852872478, "f_relative_error[%]"=>1.943788898208327}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>60.1, "time[s]"=>45.89, "y[m]"=>0.601, "x[m]"=>0.05, "T[s]"=>1.5296666666666667, "f[Hz]"=>0.653737197646546, "f_model[Hz]"=>0.6425833223660736, "f_model_possible_error[Hz]"=>0.0028491488239117285, "f_absolute_error[Hz]"=>0.011153875280472403, "f_relative_error[%]"=>1.7357866119840168}]

# %%
a_with_calc_df.plot(
  targets: [{ x: 'y[m]', y: 'f[Hz]', yerror: 'f_model_possible_error[Hz]', with: :yerrorbars }, { x: 'y[m]', y: 'f_model[Hz]', title: 'f_{m}[Hz]' }],
  options: {},
  file: 'graph/a_with_model.png'
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007f9551835250 @block=#<Proc:0x007f9551835278@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_11_10/moromoro.rb:125>>

# %%
a_with_calc_df.plot(
  targets: [{ x: 'y[m]', y: 'f_absolute_error[Hz]', title: 'Δf'}],
  options: {
    yl: 'Δf[Hz]'
  },
  file: 'graph/a_abs_error.png'
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007f9550859458 @block=#<Proc:0x007f9550859480@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_11_10/moromoro.rb:125>>

# %%
a_with_f_square = a_with_calc_df.map { |row| row.merge(
  'f2' => row['f[Hz]']**2, 'y2' => row['y[m]']**2
) }.reset
nil

# %%
a_slope = a_with_f_square.slope(x: 'y[m]', y: 'f2')
a_segment = a_with_f_square.segment(x: 'y[m]', y: 'f2')
a_with_f_square_and_regression = a_with_f_square.map do |row|
  row.merge(
    'regression' => a_slope * row['y[m]'] + a_segment
  )
end.reset
# Out:
# [{"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>30.1, "time[s]"=>34.31, "y[m]"=>0.301, "x[m]"=>0.05, "T[s]"=>1.1436666666666668, "f[Hz]"=>0.8743806470416787, "f_model[Hz]"=>0.9079949599505865, "f_model_possible_error[Hz]"=>0.005096943439473499, "f_absolute_error[Hz]"=>0.03361431290890782, "f_relative_error[%]"=>3.702037389143341, "f2"=>0.7645415159210247, "y2"=>0.09060099999999999, "regression"=>0.7395731078966038}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>35.1, "time[s]"=>36.37, "y[m]"=>0.35100000000000003, "x[m]"=>0.05, "T[s]"=>1.2123333333333333, "f[Hz]"=>0.8248556502612043, "f_model[Hz]"=>0.8408395428705104, "f_model_possible_error[Hz]"=>0.004535912291785562, "f_absolute_error[Hz]"=>0.015983892609306105, "f_relative_error[%]"=>1.9009444482997666, "f2"=>0.6803868437678342, "y2"=>0.12320100000000002, "regression"=>0.6845477908492287}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>40.1, "time[s]"=>38.3, "y[m]"=>0.401, "x[m]"=>0.05, "T[s]"=>1.2766666666666666, "f[Hz]"=>0.783289817232376, "f_model[Hz]"=>0.7866734613250321, "f_model_possible_error[Hz]"=>0.004090286251866194, "f_absolute_error[Hz]"=>0.003383644092656124, "f_relative_error[%]"=>0.4301205339960101, "f2"=>0.613542937779929, "y2"=>0.16080100000000003, "regression"=>0.6295224738018537}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>45.1, "time[s]"=>40.14, "y[m]"=>0.451, "x[m]"=>0.05, "T[s]"=>1.338, "f[Hz]"=>0.7473841554559043, "f_model[Hz]"=>0.7417856280893437, "f_model_possible_error[Hz]"=>0.003723887172176902, "f_absolute_error[Hz]"=>0.005598527366560635, "f_relative_error[%]"=>0.7547365646569693, "f2"=>0.5585830758265353, "y2"=>0.203401, "regression"=>0.5744971567544787}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>50.1, "time[s]"=>42.05, "y[m]"=>0.501, "x[m]"=>0.05, "T[s]"=>1.4016666666666666, "f[Hz]"=>0.713436385255648, "f_model[Hz]"=>0.7037976667768022, "f_model_possible_error[Hz]"=>0.003393276505377637, "f_absolute_error[Hz]"=>0.009638718478845787, "f_relative_error[%]"=>1.3695297574640224, "f2"=>0.5089914758066454, "y2"=>0.251001, "regression"=>0.5194718397071036}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>55.1, "time[s]"=>43.85, "y[m]"=>0.551, "x[m]"=>0.05, "T[s]"=>1.4616666666666667, "f[Hz]"=>0.6841505131128849, "f_model[Hz]"=>0.6711056362600124, "f_model_possible_error[Hz]"=>0.0031204128306174905, "f_absolute_error[Hz]"=>0.013044876852872478, "f_relative_error[%]"=>1.943788898208327, "f2"=>0.4680619245926237, "y2"=>0.30360100000000007, "regression"=>0.4644465226597285}, {"m[kg]"=>0.35, "x[cm]"=>5.0, "N"=>30.0, "y[cm]"=>60.1, "time[s]"=>45.89, "y[m]"=>0.601, "x[m]"=>0.05, "T[s]"=>1.5296666666666667, "f[Hz]"=>0.653737197646546, "f_model[Hz]"=>0.6425833223660736, "f_model_possible_error[Hz]"=>0.0028491488239117285, "f_absolute_error[Hz]"=>0.011153875280472403, "f_relative_error[%]"=>1.7357866119840168, "f2"=>0.4273723235867592, "y2"=>0.361201, "regression"=>0.4094212056123536}]

# %%
a_with_f_square_and_regression.plot(
  targets: [
    { x: 'y[m]', y: 'f2' },
    { x: 'y[m]', y: 'regression', with: :line, title: "y=#{'%.2f' % a_slope}x + #{'%.2f' % a_segment}" }
  ],
  options: {
    key: 'box inside left top',
  },
  file: 'graph/a_f_square_with_regression.png'
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007f95513c5ad0 @block=#<Proc:0x007f95513c5cb0@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_11_10/moromoro.rb:125>>

# %%
a_with_f_square.slope(x: 'y[m]', y: 'f2')
# Out:
# -1.1005063409475007

# %%
a_with_f_square.slope_error(x: 'y[m]', y: 'f2')
# Out:
# 0.031179929766032857

# %%
b_df = <<DATA.to_df
s_a_dash[mm], s_b_dash[mm]
-10, -0.8
-20, -2.0
-30, -2.9
-40, -4.0
-50, -4.9
-60, -5.5
-70, -6.8
-80, -8.0
-90, -8.9
10, 1.0
20, 2.1
25, 2.9
30, 3.5
35, 3.8
40, 4.1
45, 4.7
50, 5.0
55, 5.8
60, 6.3
65, 7.0
70, 7.5
75, 7.8
80, 8.0
85, 9.0
90, 9.4
DATA
nil

# %%
def s_to_theta(s)
  r = 63.5 * 10 **(-2)
  s / r
end
# Out:
# :s_to_theta

# %%
s_a_0 = 3.5 * 10**(-3)
s_b_0 = 1.0 * 10**(-3)

b_with_calc_df = b_df.map do |row|
  s_a = (row['s_a_dash[mm]'] * 10**(-3) - s_a_0)
  s_b = (row['s_b_dash[mm]'] * 10**(-3) - s_b_0)
  theta_a = s_to_theta(s_a)
  theta_b = s_to_theta(s_b)
  row.merge(
    's_a[mm]' => s_a,
    's_b[mm]' => s_b,
    'theta_a' => theta_a,
    'theta_b' => theta_b,
    'sin_theta_b' => Math.sin(theta_b),
    'delta_theta' => theta_a - theta_b
  )
end.to_a.to_df
# Out:
# [{"s_a_dash[mm]"=>-10.0, "s_b_dash[mm]"=>-0.8, "s_a[mm]"=>-0.0135, "s_b[mm]"=>-0.0018, "theta_a"=>-0.02125984251968504, "theta_b"=>-0.0028346456692913383, "sin_theta_b"=>-0.0028346418731277907, "delta_theta"=>-0.0184251968503937}, {"s_a_dash[mm]"=>-20.0, "s_b_dash[mm]"=>-2.0, "s_a[mm]"=>-0.0235, "s_b[mm]"=>-0.003, "theta_a"=>-0.03700787401574803, "theta_b"=>-0.004724409448818898, "sin_theta_b"=>-0.004724391874000212, "delta_theta"=>-0.03228346456692913}, {"s_a_dash[mm]"=>-30.0, "s_b_dash[mm]"=>-2.9, "s_a[mm]"=>-0.0335, "s_b[mm]"=>-0.0039, "theta_a"=>-0.05275590551181102, "theta_b"=>-0.0061417322834645665, "sin_theta_b"=>-0.006141693671617647, "delta_theta"=>-0.046614173228346455}, {"s_a_dash[mm]"=>-40.0, "s_b_dash[mm]"=>-4.0, "s_a[mm]"=>-0.043500000000000004, "s_b[mm]"=>-0.005, "theta_a"=>-0.06850393700787402, "theta_b"=>-0.007874015748031496, "sin_theta_b"=>-0.0078739343832916, "delta_theta"=>-0.060629921259842526}, {"s_a_dash[mm]"=>-50.0, "s_b_dash[mm]"=>-4.9, "s_a[mm]"=>-0.053500000000000006, "s_b[mm]"=>-0.005900000000000001, "theta_a"=>-0.08425196850393701, "theta_b"=>-0.009291338582677167, "sin_theta_b"=>-0.009291204897968468, "delta_theta"=>-0.07496062992125985}, {"s_a_dash[mm]"=>-60.0, "s_b_dash[mm]"=>-5.5, "s_a[mm]"=>-0.0635, "s_b[mm]"=>-0.0065, "theta_a"=>-0.1, "theta_b"=>-0.010236220472440945, "sin_theta_b"=>-0.01023604171448976, "delta_theta"=>-0.08976377952755907}, {"s_a_dash[mm]"=>-70.0, "s_b_dash[mm]"=>-6.8, "s_a[mm]"=>-0.07350000000000001, "s_b[mm]"=>-0.0078, "theta_a"=>-0.11574803149606301, "theta_b"=>-0.012283464566929133, "sin_theta_b"=>-0.012283155673901537, "delta_theta"=>-0.10346456692913387}, {"s_a_dash[mm]"=>-80.0, "s_b_dash[mm]"=>-8.0, "s_a[mm]"=>-0.0835, "s_b[mm]"=>-0.009000000000000001, "theta_a"=>-0.131496062992126, "theta_b"=>-0.014173228346456694, "sin_theta_b"=>-0.014172753830588686, "delta_theta"=>-0.1173228346456693}, {"s_a_dash[mm]"=>-90.0, "s_b_dash[mm]"=>-8.9, "s_a[mm]"=>-0.0935, "s_b[mm]"=>-0.009899999999999999, "theta_a"=>-0.14724409448818898, "theta_b"=>-0.01559055118110236, "sin_theta_b"=>-0.015589919601814198, "delta_theta"=>-0.13165354330708662}, {"s_a_dash[mm]"=>10.0, "s_b_dash[mm]"=>1.0, "s_a[mm]"=>0.006500000000000001, "s_b[mm]"=>0.0, "theta_a"=>0.010236220472440946, "theta_b"=>0.0, "sin_theta_b"=>0.0, "delta_theta"=>0.010236220472440946}, {"s_a_dash[mm]"=>20.0, "s_b_dash[mm]"=>2.1, "s_a[mm]"=>0.0165, "s_b[mm]"=>0.0011000000000000003, "theta_a"=>0.025984251968503937, "theta_b"=>0.0017322834645669295, "sin_theta_b"=>0.0017322825981926234, "delta_theta"=>0.02425196850393701}, {"s_a_dash[mm]"=>25.0, "s_b_dash[mm]"=>2.9, "s_a[mm]"=>0.021500000000000002, "s_b[mm]"=>0.0018999999999999998, "theta_a"=>0.03385826771653543, "theta_b"=>0.002992125984251968, "sin_theta_b"=>0.0029921215195941185, "delta_theta"=>0.030866141732283463}, {"s_a_dash[mm]"=>30.0, "s_b_dash[mm]"=>3.5, "s_a[mm]"=>0.0265, "s_b[mm]"=>0.0025, "theta_a"=>0.04173228346456693, "theta_b"=>0.003937007874015748, "sin_theta_b"=>0.003936997703399615, "delta_theta"=>0.03779527559055118}, {"s_a_dash[mm]"=>35.0, "s_b_dash[mm]"=>3.8, "s_a[mm]"=>0.0315, "s_b[mm]"=>0.0028, "theta_a"=>0.049606299212598425, "theta_b"=>0.004409448818897638, "sin_theta_b"=>0.004409434529917071, "delta_theta"=>0.045196850393700784}, {"s_a_dash[mm]"=>40.0, "s_b_dash[mm]"=>4.1, "s_a[mm]"=>0.0365, "s_b[mm]"=>0.0030999999999999995, "theta_a"=>0.057480314960629914, "theta_b"=>0.004881889763779527, "sin_theta_b"=>0.0048818703722467915, "delta_theta"=>0.05259842519685039}, {"s_a_dash[mm]"=>45.0, "s_b_dash[mm]"=>4.7, "s_a[mm]"=>0.041499999999999995, "s_b[mm]"=>0.0037, "theta_a"=>0.06535433070866141, "theta_b"=>0.005826771653543307, "sin_theta_b"=>0.005826738682551708, "delta_theta"=>0.059527559055118105}, {"s_a_dash[mm]"=>50.0, "s_b_dash[mm]"=>5.0, "s_a[mm]"=>0.0465, "s_b[mm]"=>0.004, "theta_a"=>0.0732283464566929, "theta_b"=>0.006299212598425197, "sin_theta_b"=>0.006299170939631879, "delta_theta"=>0.06692913385826771}, {"s_a_dash[mm]"=>55.0, "s_b_dash[mm]"=>5.8, "s_a ...

# %%
b_with_calc_df.slice('s_a[mm]', 's_b[mm]').map { |row| { 's_A[mm]' => '%.1e' % row['s_a[mm]'], 's_B[mm]' => '%.1e' % row['s_b[mm]'] } }.reset.save_csv('csv/B.csv')
# Out:
# "csv/B.csv"

# %%
b_with_calc_df.plot(
  targets: [{ x: 'sin_theta_b', y: 'delta_theta', title: '' }],
  options: {
    nokey: '',
    yl: 'θ_A - θ_B[rad]',
    xl: 'sin θ_B'
  },
  file: 'graph/b.png'
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007f95538084b0 @block=#<Proc:0x007f95538084d8@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_11_10/moromoro.rb:125>>

# %%
b_slope = b_with_calc_df.slope(x: 'sin_theta_b', y: 'delta_theta')
# Out:
# 8.854226559826333

# %%
b_slope_error = b_with_calc_df.slope_error(x: 'sin_theta_b', y: 'delta_theta')
# Out:
# 0.000547080795105795

# %%
b_segment = b_with_calc_df.segment(x: 'sin_theta_b', y: 'delta_theta')
# Out:
# 0.00688400981627587

# %%
b_with_calc_df.map do |row|
  row.merge(
    'linear_regression' => row['sin_theta_b'] * (b_slope + b_slope_error) + b_segment,
  )
end.to_a.to_df.plot(
  targets: [
    { x: 'sin_theta_b', y: 'delta_theta', title: 'sin θ_B' },
    { x: 'sin_theta_b', y: 'linear_regression', with: :line, title: "y=#{'%.2f' % b_slope}x + #{'%.2f' % b_segment}" }],
  options: {
    key: 'box inside left top',
    yl: 'θ_A - θ_B[rad]',
    xl: 'sin θ_B'
  },
  file: 'graph/b_with_regression.png'
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007f9550e7d348 @block=#<Proc:0x007f9550e7d370@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_11_10/moromoro.rb:125>>

# %%
omega_1 = 1/((39.17 + 39.19)/2/30) * 2 * Math::PI
# Out:
# 4.8110147834453185

# %%
omega_2 = 1/((35.56 + 35.54)/2/30) * 2 * Math::PI
# Out:
# 5.3022660820080905

# %%
t_ab_model = (2*Math::PI)/(omega_2 - omega_1)
# Out:
# 12.790165289256173

# %%
t_ab = ((11.90 + 12.05 + 12.27 + 11.83 + 12.21)/5)
# Out:
# 12.052

# %%
(((t_ab - t_ab_model).abs / t_ab_model)*100).round
# Out:
# 6

# %%
dTab_domega1 = 2 * Math::PI / (omega_2 - omega_1)**2
# Out:
# 26.035891053470365

# %%
dTab_domega2 = - 2 * Math::PI / (omega_2 - omega_1)**2
# Out:
# -26.035891053470365

# %%
domega1 = -60*Math::PI/(39.18)**2 * 0.2
# Out:
# -0.02455852365209453

# %%
domega2 = -60*Math::PI/(35.55)**2 * 0.2
# Out:
# -0.02982990763436338

# %%
Math.sqrt(dTab_domega1**2 * domega1**2+ dTab_domega2**2 * domega2**2).round(1)
# Out:
# 1.0

# %%
q = b_slope.round(2)
# Out:
# 8.85

# %%
omega_0 = 2 * Math::PI * 0.7474 # 実験Aでy=0.45[m]のときのfの値より
# Out:
# 4.696052698586023

# %%
t_ab_by_q = 2*Math::PI/(omega_0*(Math.sqrt(1 + 2/q) - 1))
# Out:
# 12.475988160409615

# %%
1/(0.08)
# Out:
# 12.5

# %%
5/63.5
# Out:
# 0.07874015748031496

# %%
f_1 = 1/((39.17 + 39.19)/2 / 30)
# Out:
# 0.7656967840735068

# %%
f_2 = 1/((35.56 + 35.54)/2 / 30)
# Out:
# 0.8438818565400845

# %%
f_2 - f_1
# Out:
# 0.07818507246657769

# %%
f_AB = 1/([11.90, 12.05, 12.27, 11.83, 12.21].inject(:+)/5)
# Out:
# 0.0829737802854298

# %%
def calc_theta_a(t, f)
  Math.cos(2 * Math::PI * f * t)
end

def calc_theta_b(t, f)
  Math.sin(2 * Math::PI * f * t)
end

ts = [*0..2000].map { |i| i.to_f / 100 }
t_to_theta = ts.map do |t|
  {
    t: t,
    theta_a_by_f1_f2: calc_theta_a(t, (f_2 - f_1)),
    theta_b_by_f1_f2: calc_theta_b(t, (f_2 - f_1)),
    theta_a_by_f_ab: calc_theta_a(t, f_AB),
    theta_b_by_f_ab: calc_theta_b(t, f_AB),
  }
end.to_df
nil

# %%
t_to_theta.plot(
  targets: [
    { x: :t, y: :theta_a_by_f1_f2, title: 'θ_A(f_2 - f_1)', with: :line },
    { x: :t, y: :theta_b_by_f1_f2, title: 'θ_B(f_2 - f_1)', with: :line },
    { x: :t, y: :theta_a_by_f1_f2, title: 'θ_A(f_2 - f_1)', with: :line },
    { x: :t, y: :theta_b_by_f1_f2, title: 'θ_B(f_2 - f_1)', with: :line },
  ],
  options: {
    key: 'box inside left top',
    yl: 'θ[rad]',
    xl: 't[s]'
  },
  file: 'graph/t_to_amp_f1_f2.png'
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007f9551ae98e8 @block=#<Proc:0x007f9551ae9910@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_11_10/moromoro.rb:125>>
