# %%
require './moromoro'
# Out:
# true

# %%
(467.8 + 466.2)/2
# Out:
# 467.0

# %%
elem_dict = { 0 => 'Na', 1 => 'Hg', 2 => 'Cd' }
raw_data = <<DATA.to_df
scale, lambda[nm], element
2.23, 589.3, 0
2.30, 579.1, 1
2.31, 577.0, 1
2.57, 546.1, 1
4.01, 435.8, 1
1.94, 643.8, 2
2.92, 508.6, 2
1.65, 738.5, 2
2.14, 610.6, 2
2.85, 515.5, 2
3.28, 480.0, 2
3.46, 467.0, 2
3.91, 441.5, 2
2.12, 615.8, 0
2.39, 568.6, 0
3.03, 498.1, 0
2.83, 515.2, 0
3.13, 491.6, 1
4.66, 407.8, 1
4.75, 404.7, 1
DATA
variance_df = raw_data.map do |row|
  row.merge(
    'lambda_square_inverse[(nm)^2]' => 1.0/row['lambda[nm]']**2,
    'element' => elem_dict[row['element'].to_i]
  )
end.to_df
variance_df.plot(
  targets: [{x: 'scale', y: 'lambda[nm]' }]
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007f9637a7a678 @block=#<Proc:0x007f9637a7a6a0@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_12_08/moromoro.rb:131>>

# %%
variance_df.map do |row|
  { '{\\rm scale}': '%.2f' % row['scale'], '\\lambda[{\\rm nm}]': row['lambda[nm]'], '{\\rm element}': row['element'] }
end.reset.save_csv('csv/bunsan.csv')
# Out:
# "csv/bunsan.csv"

# %%
traces = variance_df.group_by { |row| row['element'] }.map do |element, rows|
  {xs: rows.to_df.by_col('scale'), ys: rows.to_df.by_col('lambda[nm]'), element: element }
end.map { |trace| [trace[:xs], trace[:ys], { title: trace[:element] }] }
<<COMMENT
  set 'arrow 1 from 1.87,400 to 1.87,750 nohead'
  set 'arrow 2 from 3.20,400 to 3.20,750 nohead'
  set 'arrow 3 from 4.05,400 to 4.05,750 nohead'
  set 'arrow 4 from 4.59,400 to 4.59,750 nohead'
  set 'arrow 5 from 1,434.1 to 5,434.1 nohead'
  set 'arrow 6 from 1,656.2 to 5,656.2 nohead'
  set 'arrow 7 from 1,486.1 to 5,486.1 nohead'
  set 'arrow 8 from 1,410.2 to 5,410.2 nohead'
COMMENT
plot = Proc.new do |plt, traces|
  plt.set tics: 'scale 3 font ",20"'
  plt.set mxtics: ''
  plt.set mytics: ''
  plt.set grid: 'xtics ytics mxtics mytics'
  plt.set key: 'box'
  plt.set xl: "'scale' font ',20'"
  plt.set yl: "'λ[nm]' font ',20'"
  plt.set bmargin: 6
  plt.set lmargin: 20

  
  plt.plot *traces
end
Numo.gnuplot do
  set terminal: 'png'
  set output: 'graph/bunsan.png'
  plot.call(self, traces)
end
Numo.noteplot do
  plot.call(self, traces)
end
# Out:
# #<Numo::Gnuplot::NotePlot:0x007f96381afa38 @block=#<Proc:0x007f96381afa60@(pry):1048>>

# %%
variance_df.map do |row|
  row.merge(
    '1/λ^2 [(nm)^2]' => row['lambda_square_inverse[(nm)^2]']
  )
end.plot(
  targets: [{x: 'scale', y: '1/λ^2 [(nm)^2]' }],
  options: {
    nokey: '',
    'format x': '"%.2f"',
    'format y': '"%1.1t×10^{%L}"',
  }
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007f963a1bd500 @block=#<Proc:0x007f963a1bd528@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_12_08/moromoro.rb:131>>

# %%
l = 2
x0 = 0.25
y0 = 0
h_df = <<DATA.to_df
lambda[nm], scale, n
656.2, 1.87, 3
486.1, 3.20, 4
434.1, 4.05, 5
410.2, 4.59, 6
DATA
h_with_calc = h_df.map do |row|
  row.merge(
    'lambda_inverse' => 1/(row['lambda[nm]'] * 10**(-9)),
    'n_square_inverse' => 1/row['n']**2
  )
end.reset
# Out:
# [{"lambda[nm]"=>656.2, "scale"=>1.87, "n"=>3.0, "lambda_inverse"=>1523925.6324291374, "n_square_inverse"=>0.1111111111111111}, {"lambda[nm]"=>486.1, "scale"=>3.2, "n"=>4.0, "lambda_inverse"=>2057189.8786257966, "n_square_inverse"=>0.0625}, {"lambda[nm]"=>434.1, "scale"=>4.05, "n"=>5.0, "lambda_inverse"=>2303616.6781847496, "n_square_inverse"=>0.04}, {"lambda[nm]"=>410.2, "scale"=>4.59, "n"=>6.0, "lambda_inverse"=>2437835.2023403216, "n_square_inverse"=>0.027777777777777776}]

# %%
h_with_calc.save_csv('csv/h.csv')
# Out:
# "csv/h.csv"

# %%
slope = h_with_calc.slope(x: 'n_square_inverse', y: 'lambda_inverse')
segment = p h_with_calc.segment(x: 'n_square_inverse', y: 'lambda_inverse')
h_with_calc.plot(
  targets: [
    {x: 'lambda_inverse', y: 'n_square_inverse'},
  ],
  options: {
    nokey: ''
  }
)
# Out:
# 2742405.860786482
# #<Numo::Gnuplot::NotePlot:0x007f96380b5948 @block=#<Proc:0x007f96380b5970@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_12_08/moromoro.rb:131>>

# %%
'%e' % h_with_calc.slope(x: 'n_square_inverse', y: 'lambda_inverse')
# Out:
# "-1.096594e+07"

# %%
h_with_calc.slope_error(x: 'n_square_inverse', y: 'lambda_inverse')
# Out:
# 170.0577273954458

# %%
h_with_calc.segment(x: 'n_square_inverse', y: 'lambda_inverse') * 4
# Out:
# 10969623.443145929
