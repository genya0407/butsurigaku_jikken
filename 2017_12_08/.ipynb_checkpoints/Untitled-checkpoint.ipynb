# %%
require './moromoro'
# Out:
# true

# %%
(467.8 + 466.2)/2
# Out:
# 467.0

# %%
elem_dict = { 0 => 'Na', 1 => 'Hg', 2 => 'Cd' }
raw_data = <<DATA.to_df
scale, lambda[nm], element
2.23, 589.3, 0
2.30, 579.1, 1
2.31, 577.0, 1
2.57, 546.1, 1
4.01, 435.8, 1
1.94, 643.8, 2
2.92, 508.6, 2
1.65, 738.5, 2
2.14, 610.6, 2
2.85, 515.5, 2
3.28, 480.0, 2
3.46, 467.0, 2
3.91, 441.5, 2
2.12, 615.8, 0
2.39, 568.6, 0
3.03, 498.1, 0
2.83, 515.2, 0
3.13, 491.6, 1
4.66, 407.8, 1
4.75, 404.7, 1
DATA
variance_df = raw_data.map do |row|
  row.merge(
    'lambda_square_inverse[(nm)^2]' => 1.0/row['lambda[nm]']**2,
    'element' => elem_dict[row['element'].to_i]
  )
end.to_df
variance_df.plot(
  targets: [{x: 'scale', y: 'lambda[nm]' }]
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007fcbdcadecb0 @block=#<Proc:0x007fcbdcadecd8@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_12_08/moromoro.rb:125>>

# %%
traces = variance_df.group_by { |row| row['element'] }.map do |element, rows|
  {xs: rows.to_df.by_col('scale'), ys: rows.to_df.by_col('lambda[nm]'), element: element }
end.map { |trace| [trace[:xs], trace[:ys], { title: trace[:element] }] }
Numo.noteplot do
  set 'arrow 1 from 1.87,400 to 1.87,750 nohead'
  set 'arrow 2 from 3.20,400 to 3.20,750 nohead'
  set 'arrow 3 from 4.05,400 to 4.05,750 nohead'
  set 'arrow 4 from 4.59,400 to 4.59,750 nohead'
  set 'arrow 5 from 1,434.1 to 5,434.1 nohead'
  set 'arrow 6 from 1,656.2 to 5,656.2 nohead'
  set 'arrow 7 from 1,486.1 to 5,486.1 nohead'
  set 'arrow 8 from 1,410.2 to 5,410.2 nohead'
  plot *traces
end
# Out:
# #<Numo::Gnuplot::NotePlot:0x007fcbdd17e7a0 @block=#<Proc:0x007fcbdd17e818@(pry):434>>

# %%
variance_df.plot(
  targets: [{x: 'scale', y: 'lambda_square_inverse[(nm)^2]'}],
  options: { nokey: '' }
)
# Out:
# #<Numo::Gnuplot::NotePlot:0x007fcbddd52ef0 @block=#<Proc:0x007fcbddd52f18@/Users/sangenya/Dropbox/document/univ/butsurigaku_jikken/2017_12_08/moromoro.rb:125>>

# %%
l = 2
x0 = 0.25
y0 = 0
h_df = <<DATA.to_df
lambda[nm], scale, n
656.2, 1.87, 3
486.1, 3.20, 4
434.1, 4.05, 5
410.2, 4.59, 6
DATA
rows = h_df.map do |row|
  row.merge(
    'lambda_inverse' => 1/row['lambda[nm]'],
    'x' => (1/l**2 - 1/row['n']**2)
  )
end.reset.map do |row|
  w = (row['x'] - x0)*(row['lambda_inverse'] - y0)
  z = (row['x'] - x0)**2
  [w, z]
end.to_a
# Out:
# [[-0.0005503064783771884, 0.13040123456790123], [-0.0006428718370705617, 0.09765625], [-0.0006680488366735774, 0.0841], [-0.0006771764450945339, 0.0771604938271605]]

# %%
up = 0.0
down = 0.0
rows.each do |u, d|
  up += u
  down += d
end
up/down
# Out:
# Error: Cannot find local context. Did you use `binding.pry`?
